# %%
from dotmotif.executors.NeuPrintExecutor import NeuPrintExecutor
from dotmotif import Motif

# %%
E = NeuPrintExecutor(host='https://neuprint.janelia.org/', dataset='hemibrain:v1.2.1',
                         token="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImthbGVtdUBjb2xsZWdlLmhhcnZhcmQuZWR1IiwibGV2ZWwiOiJub2F1dGgiLCJpbWFnZS11cmwiOiJodHRwczovL2xoMy5nb29nbGV1c2VyY29udGVudC5jb20vYS0vQU9oMTRHZ1VOWHdGTVFiQXRwX1RNdFY1SDc5aE9XcURVTHMyWlVmRHhpanFIQT1zOTYtYz9zej01MD9zej01MCIsImV4cCI6MTgyNzcwNTIzOH0.rfPnsUvCWU-x-XOB0VPMijfpfb0JVPm1liT-7NK6ViE"
)

# %%
motif = Motif('''
 B -> A
 B.status = "Traced"
 A.status = "Traced"
 A.INP = True
''')
motif._node_constraints['A']['status']['='] = ['Orphan']

# %%
motif._node_constraints['A']
# Out:
# {'status': {'=': ['Orphan']}, 'INP': {'=': [True]}}

# %%
motif._node_constraints['A']['AVLP(R)'] = {}
motif._node_constraints['A']['AVLP(R)']['='] = [True]
motif._node_constraints['A']
# Out:
#   Input In [32]
#     motif._node_constraints['A'][`'AVLP(R)'`] = {}
#                                  ^
# SyntaxError: invalid syntax

# %%
results = E.find(motif, limit=1)
results
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/neuronal-motifs/lib/python3.9/site-packages/neuprint/client.py:228, in verbose_errors.<locals>.wrapper(*args, **kwargs)
#     227 try:
# --> 228     return f(*args, **kwargs)
#     229 except RequestException as ex:
#     230     # If the error response body is non-empty, show that in the traceback, too.
#     231     # neuprint-http error messages are often helpful -- show them!
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neuronal-motifs/lib/python3.9/site-packages/neuprint/client.py:382, in Client._fetch(self, url, json, ispost)
#     381     r = self.session.get(url, verify=self.verify)
# --> 382 r.raise_for_status()
#     383 return r
#
# ...

# %%
# Out:
#                                                    B  \
# 0  {'AL(R)': True, 'AL-V(R)': True, 'AL-VC2(R)': ...
#
#                                                    A
# 0  {'AVLP(R)': True, 'INP': True, 'LH(R)': True, ...

# %%
results['A'][0]
# Out:
# {'AVLP(R)': True,
#  'INP': True,
#  'LH(R)': True,
#  'SCL(R)': True,
#  'VLNP(R)': True,
#  'bodyId': 1010248735,
#  'downstream': 0,
#  'mito': 1,
#  'post': 10,
#  'pre': 0,
#  'roiInfo': '{"INP": {"post": 2}, "SCL(R)": {"post": 2}, "LH(R)": {"post": 3}, "VLNP(R)": {"post": 5}, "AVLP(R)": {"post": 5}}',
#  'size': 1014700,
#  'status': 'Orphan',
#  'statusLabel': 'Orphan',
#  'upstream': 10}

# %%
for key in prop_dict:
    try:
        prop_dict[key] = set(prop_dict[key])
    except TypeError as err:
        print(err)
        prop_dict[key] = None
import pickle
pickle.dump( prop_dict, open( "savhe.p", "wb" ) )
# Out:
# unhashable type: 'dict'

# %%
import pickle
test = pickle.load(open( "save.p", "rb" ) )

# %%
test
# Out:
# {'CRE(-ROB,-RUB)(R)': {True},
#  'CRE(-RUB)(L)': {True},
#  'CRE(L)': {True},
#  'CRE(R)': {True},
#  'INP': {True},
#  'MB(+ACA)(R)': {True},
#  'MB(L)': {True},
#  'MB(R)': {True},
#  'SIP(L)': {True},
#  'SMP(L)': {True},
#  'SNP(L)': {True},
#  "b'2(R)": {True},
#  "b'L(L)": {True},
#  "b'L(R)": {True},
#  'bodyId': {797442049,
#   1098776577,
#   1170866180,
#   1073086468,
#   1297612811,
#   1234567194,
#   1629880348,
#   2247884839,
#   1475477547,
#   796393522,
#   1479147574,
#   924188746,
#   1723990099,
#   1251999828,
#   1997537373,
#   1882325087,
#   1170866275,
#   2031616103,
#   2125070447,
#   1756364911,
#   1011482740,
#   1234567286,
#   2341339261,
#   1219756158,
#   1438515327,
#   457179265,
#   668074117,
#   1262485643,
#   1380188301,
#   1137180814,
#   390594712,
#   391643292,
#   1262485663,
#   542376096,
#   1904083110,
#   1018691751,
#   2095710384,
#   1325138101,
#   1007550646,
#   363724985,
#   1438515387,
#   1007550653,
#   483000509,
# ...

# %%
motif = Motif(m)
results = E.find(motif, limit=lim)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 motif = Motif(m)
#       2 results = E.find(motif, limit=lim)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neuronal-motifs/lib/python3.9/site-packages/dotmotif/__init__.py:87, in Motif.__init__(self, input_motif, **kwargs)
#      84 self._automorphisms = []
#      86 if input_motif:
# ---> 87     self.from_motif(input_motif)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/neuronal-motifs/lib/python3.9/site-packages/dotmotif/__init__.py:100, in Motif.from_motif(self, cmd)
#      89 def from_motif(self, cmd: str):
#      90     """
#      91     Ingest a dotmotif-format string.
#      92
#    (...)
#      98
#      99     """
# --> 100     if len(cmd.split("\n")) == 1:
#     101         try:
#     102             cmd = open(cmd, "r").read()
#
# ...
